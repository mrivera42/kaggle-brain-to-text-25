# %%
import pandas as pd 
import numpy as np

# %%
ids = []
sentences = []
for i in range(0,1450):

    ids.append(i)
    sentences.append('This is a test sentence')

submission_df = pd.DataFrame(
    {
        'id': ids,
        'text': sentences
    }
)

submission_df.head()
# Out:
#    ids                sentences
# 0    0  This is a test sentence
# 1    1  This is a test sentence
# 2    2  This is a test sentence
# 3    3  This is a test sentence
# 4    4  This is a test sentence

# %%
submission_df.shape
# Out:
# (1450, 2)

# %%
submission_df.to_csv('submission.csv')
